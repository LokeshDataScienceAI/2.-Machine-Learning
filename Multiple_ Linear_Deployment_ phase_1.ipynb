# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalized_model_Multiplelinear.sav",'rb'))
result=loaded_model.predict([[2468,3445,6556,877,90]])
# Out:
# C:\Users\lokes\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[478171.41323966]])
