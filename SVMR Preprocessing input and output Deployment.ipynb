# %%
import pandas as pd
dataset = pd.read_csv('50_Startups.csv')
datasets=pd.get_dummies(dataset,drop_first=True)
independent=datasets[['R&D Spend','Administration', 'Marketing Spend','State_Florida', 'State_New York']]
dependent=datasets[['Profit']]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
scy=StandardScaler()
y_train=scy.fit_transform(y_train)
y_test=scy.transform(y_test)

# %%
preinput=sc.transform([[1300,12000,4000,0,1]])
# Out:
# C:\Users\lokes\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.41240431, -4.30496048, -1.44694752, -0.42257713,  1.24034735]])

# %%
import pickle
loaded_model=pickle.load(open("Finalized_simple_vector_machine.sav", 'rb'))
result=loaded_model.predict(preinput)
# Out:
# C:\Users\lokes\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([37953.03466297])

# %%
preoutput=scy.inverse_transform([result])

# %%
preoutput
# Out:
# array([[1.64571535e+09]])
